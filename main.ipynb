# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220716195849_single_8core_4096'
)
# Out:
# found converted file: ./ctfs/trace-reference-system-20220716195849_single_8core_4096/converted
# 21476 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#      /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0               26.214                 6377.749          19084.973
# 1                6.243                 6050.555           6101.593
# 2                8.288                 6134.754           6730.823
# 3                8.431                 6261.832           7034.914
# 4               11.426                 6605.482           7195.166
# ..                 ...                      ...                ...
# 248                NaN                      NaN                NaN
# 249                NaN                      NaN                NaN
# 250                NaN                      NaN                NaN
# 251                NaN                      NaN                NaN
# 252                NaN                      NaN                NaN
#
#      /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0            6184.491                   6185.530                   6276.725
# 1            6140.632                   6243.713                   6273.170
# 2            6314.719                   6275.154                   6470.100
# 3            6824.500                   6870.960                   6714.031
# 4            6626.990                   7066.573                   7004.875
# ..                ...                        ...                        ...
# 248               NaN                        NaN                        NaN
# 249               NaN                        NaN                        NaN
# 250               NaN                        NaN                        NaN
# 251               NaN                        NaN                        NaN
# 252               NaN                        NaN                        NaN
#
#      /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0            6188.972        6176.502           6180.185              1.021
# 1            6120.731        6116.593           6180.300             71.866
# 2            6176.925        6455.868           6396.947             64.053
# 3            6542.577        6799.214           6786.085             46.507
# 4            6457.623        6690.143           6948.236             71.401
# ..                ...             ...                ...                ...
# 248               NaN             NaN                NaN                NaN
# 249               NaN             NaN                NaN                NaN
# 250               NaN             NaN                NaN                NaN
# 251               NaN             NaN                NaN                NaN
# 252               NaN             NaN                NaN                NaN
#
#      ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0    ...      24928.981                6179.616            6182.855
# 1    ...      24994.509                6202.785            6102.518
# 2    ...      25870.379                6713.606            6882.265
# 3    ...      47351.626                6816.333            7049.090
# 4    ...      42523.664                6998.525            6584.577
# ..   ...            ...                     ...                 ...
# 248  ...            NaN                     NaN                 NaN
# 249  ...            NaN                     NaN                 NaN
# 250  ...            NaN                     NaN                 NaN
# 251  ...            NaN                     NaN                 NaN
# 252  ...            NaN                     NaN                 NaN
#
#      /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0        6179.416           6185.205          11.948              6183.464
# 1        6702.311           6185.491           5.896              6162.475
# 2        6588.542           6401.526          11.112              6291.523
# 3        6972.775           6796.037           7.996              7017.205
# 4        6523.476           6961.353           6.117              7107.413
# ..            ...                ...             ...                   ...
# 248           NaN                NaN             NaN                   NaN
# 249           NaN                NaN             NaN                   NaN
# 250           NaN                NaN             NaN                   NaN
# 251           NaN                NaN             NaN                   NaN
# 252           NaN                NaN             NaN                   NaN
#
#      /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0         15.874        11.235                     35.073
# 1          5.892         6.278                     12.345
# 2          6.437         4.192                     11.486
# 3          4.792         6.045                      8.537
# 4          4.336         6.497                      6.196
# ..           ...           ...                        ...
# 248          NaN           NaN                      4.121
# 249          NaN           NaN                      4.296
# 250          NaN           NaN                      7.489
# 251          NaN           NaN                      4.152
# 252          NaN           NaN                      4.502
#
# [253 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront              40486.324490
# PointsTransformerFront~PointCloudFusion              49862.819367
# PointCloudFusion~RayGroundFilter                     34299.491367
# RayGroundFilter~EuclideanClusterDetector             45076.943351
# EuclideanClusterDetector~ObjectCollisionEstimator     5072.950309
# ObjectCollisionEstimator~BehaviorPlanner             68487.345385
# BehaviorPlanner~MPCController                        45169.876316
# MPCController~VehicleInterface                       54369.272612
# VehicleInterface~VehicleDBWSystem                    43789.402474
# RearLidarDriver~PointsTransformerRear                47551.206224
# PointsTransformerRear~PointCloudFusion               42628.235571
# PointCloudFusion~VoxelGridDownsampler                26175.901418
# VoxelGridDownsampler~NDTLocalizer                    46660.615887
# NDTLocalizer~Lanelet2GlobalPlanner                   32048.885395
# Lanelet2GlobalPlanner~Lanelet2MapLoader              33724.516642
# Lanelet2MapLoader~LanePlanner                        27595.565815
# LanePlanner~BehaviorPlanner                          47104.568638
# BehaviorPlanner~VehicleInterface                     61506.965163
# PointCloudMap~PointCloudMapLoader                    47445.972012
# PointCloudMapLoader~NDTLocalizer                     51092.191171
# NDTLocalizer~BehaviorPlanner                         38225.869136
# Visualizer~Lanelet2GlobalPlanner                     37145.948515
# Lanelet2GlobalPlanner~BehaviorPlanner                39892.635519
# Lanelet2Map~Lanelet2MapLoader                        71986.000388
# Lanelet2MapLoader~BehaviorPlanner                    45529.166802
# EuclideanClusterSettings~EuclideanClusterDetector    35599.075269
# dtype: float64
