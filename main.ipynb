# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220622100120_single_4core'
)
# Out:
# Succeed to find record_cpp_impl. the C++ version will be used.
# found converted file: ./ctfs/trace-reference-system-20220622100120_single_4core/converted
# 25438 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#      /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0               54.213                 3574.323           6353.850
# 1               31.982                 3467.860           7471.657
# 2               44.865                 3372.769           6344.942
# 3               19.156                 3270.984           6218.962
# 4                8.436                 3124.315           3057.116
# ..                 ...                      ...                ...
# 393                NaN                      NaN                NaN
# 394                NaN                      NaN                NaN
# 395                NaN                      NaN                NaN
# 396                NaN                      NaN                NaN
# 397                NaN                      NaN                NaN
#
#      /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0            3045.343                   3078.698                   3108.604
# 1            3759.808                   3701.285                   3900.085
# 2            3047.127                   3427.966                   3052.338
# 3            3047.307                   3050.553                   3079.218
# 4            3321.983                   3054.922                   3054.552
# ..                ...                        ...                        ...
# 393               NaN                        NaN                        NaN
# 394               NaN                        NaN                        NaN
# 395               NaN                        NaN                        NaN
# 396               NaN                        NaN                        NaN
# 397               NaN                        NaN                        NaN
#
#      /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0           22445.138        3096.721           3088.086              1.423
# 1           13240.753        3106.440           3175.772            136.431
# 2           18758.418        3058.038           3859.876            171.287
# 3           18460.441        3035.545           3046.035            124.648
# 4           14071.922        3087.404           3060.503            119.848
# ..                ...             ...                ...                ...
# 393               NaN             NaN                NaN                NaN
# 394               NaN             NaN                NaN                NaN
# 395               NaN             NaN                NaN                NaN
# 396               NaN             NaN                NaN                NaN
# 397               NaN             NaN                NaN                NaN
#
#      ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0    ...      15980.437                3497.076            3089.117
# 1    ...      37766.082                3060.693            3038.050
# 2    ...      53143.607                3181.914            3226.951
# 3    ...      72368.653                3024.704            3018.993
# 4    ...      91287.924                3022.070            3062.576
# ..   ...            ...                     ...                 ...
# 393  ...            NaN                     NaN                 NaN
# 394  ...            NaN                     NaN                 NaN
# 395  ...            NaN                     NaN                 NaN
# 396  ...            NaN                     NaN                 NaN
# 397  ...            NaN                     NaN                 NaN
#
#      /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0        3099.006           3097.564          14.467              3347.891
# 1        3712.502           3189.589           8.376              3031.387
# 2        3042.508           3874.424          11.963              3301.948
# 3        3295.842           3054.922          39.605              3385.132
# 4        3073.147           3068.739           6.753              3073.016
# ..            ...                ...             ...                   ...
# 393           NaN                NaN             NaN                   NaN
# 394           NaN                NaN             NaN                   NaN
# 395           NaN                NaN             NaN                   NaN
# 396           NaN                NaN             NaN                   NaN
# 397           NaN                NaN             NaN                   NaN
#
#      /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0         30.758        11.242                     59.574
# 1          7.023        12.514                     24.738
# 2         10.089         6.071                     38.093
# 3          6.212         7.244                      8.175
# 4          6.793         6.823                      8.006
# ..           ...           ...                        ...
# 393          NaN           NaN                     12.524
# 394          NaN           NaN                     51.067
# 395          NaN           NaN                      7.083
# 396          NaN           NaN                     37.181
# 397          NaN           NaN                     60.175
#
# [398 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront                386.015626
# PointsTransformerFront~PointCloudFusion                674.759960
# PointCloudFusion~RayGroundFilter                      4029.949020
# RayGroundFilter~EuclideanClusterDetector              2101.328101
# EuclideanClusterDetector~ObjectCollisionEstimator     2370.528545
# ObjectCollisionEstimator~BehaviorPlanner              2065.708283
# BehaviorPlanner~MPCController                          966.265919
# MPCController~VehicleInterface                         710.827495
# VehicleInterface~VehicleDBWSystem                      778.990495
# RearLidarDriver~PointsTransformerRear                  580.617424
# PointsTransformerRear~PointCloudFusion                 678.122879
# PointCloudFusion~VoxelGridDownsampler                  789.865657
# VoxelGridDownsampler~NDTLocalizer                     4852.558919
# NDTLocalizer~Lanelet2GlobalPlanner                    1399.259205
# Lanelet2GlobalPlanner~Lanelet2MapLoader               1356.669181
# Lanelet2MapLoader~LanePlanner                         5024.725614
# LanePlanner~BehaviorPlanner                           2685.778793
# BehaviorPlanner~VehicleInterface                      4208.402535
# PointCloudMap~PointCloudMapLoader                     1836.498759
# PointCloudMapLoader~NDTLocalizer                      1457.467373
# NDTLocalizer~BehaviorPlanner                          4579.416048
# Visualizer~Lanelet2GlobalPlanner                      5411.871398
# Lanelet2GlobalPlanner~BehaviorPlanner                 4557.340566
# Lanelet2Map~Lanelet2MapLoader                        10611.895172
# Lanelet2MapLoader~BehaviorPlanner                     8303.064244
# EuclideanClusterSettings~EuclideanClusterDetector     4334.856975
# dtype: float64
