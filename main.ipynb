# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220622100120_single_4core'
)
# Out:
# found converted file: ./ctfs/trace-reference-system-20220622100120_single_4core/converted
# 25438 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#      /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0             0.054213                 3.574323           6.353850
# 1             0.031982                 3.467860           7.471657
# 2             0.044865                 3.372769           6.344942
# 3             0.019156                 3.270984           6.218962
# 4             0.008436                 3.124315           3.057116
# ..                 ...                      ...                ...
# 393                NaN                      NaN                NaN
# 394                NaN                      NaN                NaN
# 395                NaN                      NaN                NaN
# 396                NaN                      NaN                NaN
# 397                NaN                      NaN                NaN
#
#      /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0            3.045343                   3.078698                   3.108604
# 1            3.759808                   3.701285                   3.900085
# 2            3.047127                   3.427966                   3.052338
# 3            3.047307                   3.050553                   3.079218
# 4            3.321983                   3.054922                   3.054552
# ..                ...                        ...                        ...
# 393               NaN                        NaN                        NaN
# 394               NaN                        NaN                        NaN
# 395               NaN                        NaN                        NaN
# 396               NaN                        NaN                        NaN
# 397               NaN                        NaN                        NaN
#
#      /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0           22.445138        3.096721           3.088086           0.001423
# 1           13.240753        3.106440           3.175772           0.136431
# 2           18.758418        3.058038           3.859876           0.171287
# 3           18.460441        3.035545           3.046035           0.124648
# 4           14.071922        3.087404           3.060503           0.119848
# ..                ...             ...                ...                ...
# 393               NaN             NaN                NaN                NaN
# 394               NaN             NaN                NaN                NaN
# 395               NaN             NaN                NaN                NaN
# 396               NaN             NaN                NaN                NaN
# 397               NaN             NaN                NaN                NaN
#
#      ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0    ...      15.980437                3.497076            3.089117
# 1    ...      37.766082                3.060693            3.038050
# 2    ...      53.143607                3.181914            3.226951
# 3    ...      72.368653                3.024704            3.018993
# 4    ...      91.287924                3.022070            3.062576
# ..   ...            ...                     ...                 ...
# 393  ...            NaN                     NaN                 NaN
# 394  ...            NaN                     NaN                 NaN
# 395  ...            NaN                     NaN                 NaN
# 396  ...            NaN                     NaN                 NaN
# 397  ...            NaN                     NaN                 NaN
#
#      /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0        3.099006           3.097564        0.014467              3.347891
# 1        3.712502           3.189589        0.008376              3.031387
# 2        3.042508           3.874424        0.011963              3.301948
# 3        3.295842           3.054922        0.039605              3.385132
# 4        3.073147           3.068739        0.006753              3.073016
# ..            ...                ...             ...                   ...
# 393           NaN                NaN             NaN                   NaN
# 394           NaN                NaN             NaN                   NaN
# 395           NaN                NaN             NaN                   NaN
# 396           NaN                NaN             NaN                   NaN
# 397           NaN                NaN             NaN                   NaN
#
#      /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0       0.030758      0.011242                   0.059574
# 1       0.007023      0.012514                   0.024738
# 2       0.010089      0.006071                   0.038093
# 3       0.006212      0.007244                   0.008175
# 4       0.006793      0.006823                   0.008006
# ..           ...           ...                        ...
# 393          NaN           NaN                   0.012524
# 394          NaN           NaN                   0.051067
# 395          NaN           NaN                   0.007083
# 396          NaN           NaN                   0.037181
# 397          NaN           NaN                   0.060175
#
# [398 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront               0.386016
# PointsTransformerFront~PointCloudFusion               0.674760
# PointCloudFusion~RayGroundFilter                      4.029949
# RayGroundFilter~EuclideanClusterDetector              2.101328
# EuclideanClusterDetector~ObjectCollisionEstimator     2.370529
# ObjectCollisionEstimator~BehaviorPlanner              2.065708
# BehaviorPlanner~MPCController                         0.966266
# MPCController~VehicleInterface                        0.710827
# VehicleInterface~VehicleDBWSystem                     0.778990
# RearLidarDriver~PointsTransformerRear                 0.580617
# PointsTransformerRear~PointCloudFusion                0.678123
# PointCloudFusion~VoxelGridDownsampler                 0.789866
# VoxelGridDownsampler~NDTLocalizer                     4.852559
# NDTLocalizer~Lanelet2GlobalPlanner                    1.399259
# Lanelet2GlobalPlanner~Lanelet2MapLoader               1.356669
# Lanelet2MapLoader~LanePlanner                         5.024726
# LanePlanner~BehaviorPlanner                           2.685779
# BehaviorPlanner~VehicleInterface                      4.208403
# PointCloudMap~PointCloudMapLoader                     1.836499
# PointCloudMapLoader~NDTLocalizer                      1.457467
# NDTLocalizer~BehaviorPlanner                          4.579416
# Visualizer~Lanelet2GlobalPlanner                      5.411871
# Lanelet2GlobalPlanner~BehaviorPlanner                 4.557341
# Lanelet2Map~Lanelet2MapLoader                        10.611895
# Lanelet2MapLoader~BehaviorPlanner                     8.303064
# EuclideanClusterSettings~EuclideanClusterDetector     4.334857
# dtype: float64
