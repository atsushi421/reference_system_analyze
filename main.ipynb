# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220718143100_multi_8core_4096'
)
# Out:
# found converted file: ./ctfs/trace-reference-system-20220718143100_multi_8core_4096/converted
# 238692 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#       /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0                19.441                 6591.841           7812.291
# 1                17.610                 6519.633           7711.027
# 2                14.538                 6529.914           8139.007
# 3                12.448                 7763.639           7781.357
# 4                13.618                 7685.531           8219.151
# ...                 ...                      ...                ...
# 4001                NaN                      NaN                NaN
# 4002                NaN                      NaN                NaN
# 4003                NaN                      NaN                NaN
# 4004                NaN                      NaN                NaN
# 4005                NaN                      NaN                NaN
#
#       /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0             6240.833                   6799.082                   7080.853
# 1             6492.683                   6578.375                   6456.948
# 2             6539.307                   6361.801                   6685.957
# 3             7488.106                   6576.172                   6991.843
# 4             6738.907                   6548.297                   6880.290
# ...                ...                        ...                        ...
# 4001               NaN                        NaN                        NaN
# 4002               NaN                        NaN                        NaN
# 4003               NaN                        NaN                        NaN
# 4004               NaN                        NaN                        NaN
# 4005               NaN                        NaN                        NaN
#
#       /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0             6843.104        6451.080           6442.831              2.267
# 1             6558.199        6937.206           6899.729             56.827
# 2             6666.416        6598.433           6450.857             52.453
# 3             7188.579        6773.740           6576.247             91.327
# 4             7102.717        6449.372           6518.309             53.949
# ...                ...             ...                ...                ...
# 4001               NaN             NaN                NaN                NaN
# 4002               NaN             NaN                NaN                NaN
# 4003               NaN             NaN                NaN                NaN
# 4004               NaN             NaN                NaN                NaN
# 4005               NaN             NaN                NaN                NaN
#
#       ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0     ...      15643.321                6463.077            6454.106
# 1     ...      35360.110                6826.776            6459.691
# 2     ...      55801.349                6825.596            7121.555
# 3     ...      73508.739                7079.942            7068.944
# 4     ...      93362.141                7016.692            6548.558
# ...   ...            ...                     ...                 ...
# 4001  ...            NaN                     NaN                 NaN
# 4002  ...            NaN                     NaN                 NaN
# 4003  ...            NaN                     NaN                 NaN
# 4004  ...            NaN                     NaN                 NaN
# 4005  ...            NaN                     NaN                 NaN
#
#       /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0         6571.204           6453.638          20.524              6892.632
# 1         6667.962           6910.504          15.219              6979.718
# 2         6556.759           6460.867          23.505              6750.203
# 3         6663.563           6589.998          15.775              7365.017
# 4         7057.364           6529.306          15.776              6790.703
# ...            ...                ...             ...                   ...
# 4001           NaN                NaN             NaN                   NaN
# 4002           NaN                NaN             NaN                   NaN
# 4003           NaN                NaN             NaN                   NaN
# 4004           NaN                NaN             NaN                   NaN
# 4005           NaN                NaN             NaN                   NaN
#
#       /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0          24.373        51.128                     97.378
# 1          18.063        14.996                     17.496
# 2          16.331        11.868                     11.567
# 3          36.169        43.732                     11.793
# 4          13.957        40.230                     14.310
# ...           ...           ...                        ...
# 4001          NaN           NaN                     11.802
# 4002          NaN           NaN                     11.623
# 4003          NaN           NaN                     13.960
# 4004          NaN           NaN                     13.728
# 4005          NaN           NaN                     14.591
#
# [4006 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront               187.004750
# PointsTransformerFront~PointCloudFusion               210.112541
# PointCloudFusion~RayGroundFilter                      220.529747
# RayGroundFilter~EuclideanClusterDetector             1517.383302
# EuclideanClusterDetector~ObjectCollisionEstimator     136.000514
# ObjectCollisionEstimator~BehaviorPlanner             2220.107882
# BehaviorPlanner~MPCController                         188.936290
# MPCController~VehicleInterface                        161.491307
# VehicleInterface~VehicleDBWSystem                     144.279104
# RearLidarDriver~PointsTransformerRear                 211.542456
# PointsTransformerRear~PointCloudFusion                184.711090
# PointCloudFusion~VoxelGridDownsampler                 132.367310
# VoxelGridDownsampler~NDTLocalizer                     566.889360
# NDTLocalizer~Lanelet2GlobalPlanner                    144.657992
# Lanelet2GlobalPlanner~Lanelet2MapLoader               135.861056
# Lanelet2MapLoader~LanePlanner                         228.667445
# LanePlanner~BehaviorPlanner                           585.209421
# BehaviorPlanner~VehicleInterface                      281.491649
# PointCloudMap~PointCloudMapLoader                     214.136124
# PointCloudMapLoader~NDTLocalizer                      173.876147
# NDTLocalizer~BehaviorPlanner                          904.454944
# Visualizer~Lanelet2GlobalPlanner                      302.023059
# Lanelet2GlobalPlanner~BehaviorPlanner                 471.365156
# Lanelet2Map~Lanelet2MapLoader                         686.429520
# Lanelet2MapLoader~BehaviorPlanner                     847.898904
# EuclideanClusterSettings~EuclideanClusterDetector     603.397154
# dtype: float64
