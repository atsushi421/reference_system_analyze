# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220718143539_multi_8core_2048'
)
# Out:
# converting trace directory: ./ctfs/trace-reference-system-20220718143539_multi_8core_2048
# converted 238740 events in 11.3 s
# output written to: ./ctfs/trace-reference-system-20220718143539_multi_8core_2048/converted
# 238740 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#       /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0                36.088                 1774.688           2910.254
# 1                19.493                 2073.416           3790.762
# 2                36.820                 4419.809           8340.448
# 3                35.887                 1808.216           3111.568
# 4                36.175                 1808.341           3497.580
# ...                 ...                      ...                ...
# 4002                NaN                      NaN                NaN
# 4003                NaN                      NaN                NaN
# 4004                NaN                      NaN                NaN
# 4005                NaN                      NaN                NaN
# 4006                NaN                      NaN                NaN
#
#       /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0             1816.853                   1760.217                   1768.304
# 1             2261.145                   2439.703                   1673.063
# 2             1745.586                   1806.724                   1704.722
# 3             1880.569                   1822.702                   1727.655
# 4             1899.387                   1884.595                   1713.496
# ...                ...                        ...                        ...
# 4002               NaN                        NaN                        NaN
# 4003               NaN                        NaN                        NaN
# 4004               NaN                        NaN                        NaN
# 4005               NaN                        NaN                        NaN
# 4006               NaN                        NaN                        NaN
#
#       /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0            23118.727        1883.807           1927.167              2.708
# 1            22110.466        2246.168           2375.594             63.299
# 2            16862.448        2020.160           2101.517             63.726
# 3            22852.432        1794.437           1848.023             73.127
# 4            22848.326        1877.870           1836.544             81.271
# ...                ...             ...                ...                ...
# 4002               NaN             NaN                NaN                NaN
# 4003               NaN             NaN                NaN                NaN
# 4004               NaN             NaN                NaN                NaN
# 4005               NaN             NaN                NaN                NaN
# 4006               NaN             NaN                NaN                NaN
#
#       ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0     ...      19197.008                1636.872            1760.416
# 1     ...      39003.696                1672.358            1646.109
# 2     ...      52672.999                1928.583            2010.181
# 3     ...      79416.490                1840.513            1802.670
# 4     ...      99135.037                2049.444            1918.401
# ...   ...            ...                     ...                 ...
# 4002  ...            NaN                     NaN                 NaN
# 4003  ...            NaN                     NaN                 NaN
# 4004  ...            NaN                     NaN                 NaN
# 4005  ...            NaN                     NaN                 NaN
# 4006  ...            NaN                     NaN                 NaN
#
#       /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0         1818.049           1938.121          20.522              1767.265
# 1         1709.462           2389.992          19.918              2570.426
# 2         1994.937           2114.373          38.834              2642.531
# 3         1869.037           1859.373          16.510              1991.338
# 4         1861.532           1847.836          16.329              1851.244
# ...            ...                ...             ...                   ...
# 4002           NaN                NaN             NaN                   NaN
# 4003           NaN                NaN             NaN                   NaN
# 4004           NaN                NaN             NaN                   NaN
# 4005           NaN                NaN             NaN                   NaN
# 4006           NaN                NaN             NaN                   NaN
#
#       /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0          26.371        23.999                     82.503
# 1          14.577        18.689                     17.182
# 2          63.422        41.498                     11.879
# 3          21.067        15.512                     20.850
# 4          35.701        25.987                     15.106
# ...           ...           ...                        ...
# 4002          NaN           NaN                     73.925
# 4003          NaN           NaN                     54.409
# 4004          NaN           NaN                     63.862
# 4005          NaN           NaN                     66.141
# 4006          NaN           NaN                     69.912
#
# [4007 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront              422.698430
# PointsTransformerFront~PointCloudFusion              159.045448
# PointCloudFusion~RayGroundFilter                     238.192239
# RayGroundFilter~EuclideanClusterDetector             990.144013
# EuclideanClusterDetector~ObjectCollisionEstimator    145.269185
# ObjectCollisionEstimator~BehaviorPlanner             175.076941
# BehaviorPlanner~MPCController                        159.056304
# MPCController~VehicleInterface                       167.021874
# VehicleInterface~VehicleDBWSystem                    191.344883
# RearLidarDriver~PointsTransformerRear                483.945989
# PointsTransformerRear~PointCloudFusion               210.251804
# PointCloudFusion~VoxelGridDownsampler                178.311862
# VoxelGridDownsampler~NDTLocalizer                    178.063443
# NDTLocalizer~Lanelet2GlobalPlanner                   210.934549
# Lanelet2GlobalPlanner~Lanelet2MapLoader              194.395085
# Lanelet2MapLoader~LanePlanner                        235.926283
# LanePlanner~BehaviorPlanner                          511.632378
# BehaviorPlanner~VehicleInterface                     225.439135
# PointCloudMap~PointCloudMapLoader                    471.371294
# PointCloudMapLoader~NDTLocalizer                     195.425489
# NDTLocalizer~BehaviorPlanner                         409.058091
# Visualizer~Lanelet2GlobalPlanner                     367.917519
# Lanelet2GlobalPlanner~BehaviorPlanner                270.999049
# Lanelet2Map~Lanelet2MapLoader                        410.863550
# Lanelet2MapLoader~BehaviorPlanner                    518.822535
# EuclideanClusterSettings~EuclideanClusterDetector    754.696904
# dtype: float64
