# %%
from all_latency_getter import AllLatencyGetter

all_latency_getter = AllLatencyGetter(
    './architecture_files/arch_reference_system_single.yaml',
    './ctfs/trace-reference-system-20220718084728_multi_8core_8192'
)
# Out:
# Succeed to find record_cpp_impl. the C++ version will be used.
# converting trace directory: ./ctfs/trace-reference-system-20220718084728_multi_8core_8192
# converted 538749 events in 25.3 s
# output written to: ./ctfs/trace-reference-system-20220718084728_multi_8core_8192/converted
# 538749 events found.
#  [100%] [Ros2Handler]

# %%
node_df = all_latency_getter.get_all_nodes_latency_df()
node_df
# Out:
#       /FrontLidarDriver  /PointsTransformerFront  /PointCloudFusion  \
# 0                18.335                23652.432          25462.263
# 1                34.599                24605.161          26887.808
# 2                15.713                25914.915          25954.934
# 3                17.943                25614.892          25429.746
# 4                17.089                40465.093          25172.666
# ...                 ...                      ...                ...
# 9601                NaN                      NaN                NaN
# 9602                NaN                      NaN                NaN
# 9603                NaN                      NaN                NaN
# 9604                NaN                      NaN                NaN
# 9605                NaN                      NaN                NaN
#
#       /RayGroundFilter  /EuclideanClusterDetector  /ObjectCollisionEstimator  \
# 0            23857.612                  24045.665                  24703.730
# 1            25691.348                  25446.947                  46626.169
# 2            25452.997                  25448.297                  27141.408
# 3            27766.041                  25844.755                  37013.772
# 4            25173.975                  25251.407                  34982.478
# ...                ...                        ...                        ...
# 9601               NaN                        NaN                        NaN
# 9602               NaN                        NaN                        NaN
# 9603               NaN                        NaN                        NaN
# 9604               NaN                        NaN                        NaN
# 9605               NaN                        NaN                        NaN
#
#       /BehaviorPlanner  /MPCController  /VehicleInterface  /VehicleDBWSystem  \
# 0            95707.680       23832.515          23696.594              2.349
# 1            65455.977       25514.120          25272.732             79.641
# 2            97307.268       30007.628          26274.198             76.373
# 3            79871.256       28273.877          25062.443            103.094
# 4            49489.655       25155.820          26135.392             68.969
# ...                ...             ...                ...                ...
# 9601               NaN             NaN                NaN                NaN
# 9602               NaN             NaN                NaN                NaN
# 9603               NaN             NaN                NaN                NaN
# 9604               NaN             NaN                NaN                NaN
# 9605               NaN             NaN                NaN                NaN
#
#       ...  /NDTLocalizer  /Lanelet2GlobalPlanner  /Lanelet2MapLoader  \
# 0     ...      23527.015               24458.498           25430.178
# 1     ...      25512.081               25350.772           25692.776
# 2     ...      35456.525               46639.506           33155.945
# 3     ...      45304.559               31344.244           25224.958
# 4     ...      58112.358               38424.095           39556.368
# ...   ...            ...                     ...                 ...
# 9601  ...            NaN                     NaN                 NaN
# 9602  ...            NaN                     NaN                 NaN
# 9603  ...            NaN                     NaN                 NaN
# 9604  ...            NaN                     NaN                 NaN
# 9605  ...            NaN                     NaN                 NaN
#
#       /LanePlanner  /VehicleInterface  /PointCloudMap  /PointCloudMapLoader  \
# 0        33949.529          23707.682          46.276             23883.148
# 1        28394.458          25284.867          28.296             25219.822
# 2        25214.397          26286.778          16.894             25337.836
# 3        25991.251          25080.237       10114.150             25144.109
# 4        25148.817          26147.144          14.223             26102.409
# ...            ...                ...             ...                   ...
# 9601           NaN                NaN             NaN                   NaN
# 9602           NaN                NaN             NaN                   NaN
# 9603           NaN                NaN             NaN                   NaN
# 9604           NaN                NaN             NaN                   NaN
# 9605           NaN                NaN             NaN                   NaN
#
#       /Visualizer  /Lanelet2Map  /EuclideanClusterSettings
# 0          25.751        24.505                    100.435
# 1          17.312        33.224                     17.707
# 2          36.058         7.023                     37.479
# 3          16.209         7.368                     11.107
# 4          16.388         7.367                     37.482
# ...           ...           ...                        ...
# 9601          NaN           NaN                     15.402
# 9602          NaN           NaN                     15.674
# 9603          NaN           NaN                     15.907
# 9604          NaN           NaN                     16.011
# 9605          NaN           NaN                     15.638
#
# [9606 rows x 23 columns]

# %%
import yaml

jitter_src = {'node_name_dict': {
                    '/FrontLidarDriver': 0,
                    '/RearLidarDriver': 1,
                    '/PointCloudMap': 2,
                    '/Visualizer': 3,
                    '/Lanelet2Map': 4,
                    '/PointsTransformerFront': 5,
                    '/PointsTransformerRear': 6,
                    '/PointCloudMapLoader': 7,
                    '/Lanelet2GlobalPlanner': 8,
                    '/Lanelet2MapLoader': 9,
                    '/EuclideanClusterSettings': 10,
                    '/PointCloudFusion': 11,
                    '/VoxelGridDownsampler': 12,
                    '/NDTLocalizer': 13,
                    '/BehaviorPlanner': 14,
                    '/LanePlanner': 15,
                    '/RayGroundFilter': 16,
                    '/EuclideanClusterDetector': 17,
                    '/ObjectCollisionEstimator': 18,
                    '/MPCController': 19,
                    '/VehicleInterface': 20,
                    '/VehicleDBWSystem': 21
              },
              'jitter': {}}

for column_name, item in node_df.iteritems():
    item.dropna(inplace=True)
    item = item.astype(int)
    jitter_src['jitter'][column_name] = item.to_list()

with open("./reference_system_exec_jitter.yaml", "w") as f:
    yaml.dump(jitter_src, f)

# %%
edge_df = all_latency_getter.get_all_edges_latency_df()
edge_df.mean()
# Out:
# FrontLidarDriver~PointsTransformerFront                134.495914
# PointsTransformerFront~PointCloudFusion                 94.796178
# PointCloudFusion~RayGroundFilter                       125.140851
# RayGroundFilter~EuclideanClusterDetector             13642.457302
# EuclideanClusterDetector~ObjectCollisionEstimator       95.087201
# ObjectCollisionEstimator~BehaviorPlanner              9981.907275
# BehaviorPlanner~MPCController                           93.968468
# MPCController~VehicleInterface                          99.425547
# VehicleInterface~VehicleDBWSystem                       97.357577
# RearLidarDriver~PointsTransformerRear                  155.030987
# PointsTransformerRear~PointCloudFusion                  86.371471
# PointCloudFusion~VoxelGridDownsampler                  102.323794
# VoxelGridDownsampler~NDTLocalizer                     2578.415453
# NDTLocalizer~Lanelet2GlobalPlanner                      92.363883
# Lanelet2GlobalPlanner~Lanelet2MapLoader                102.847475
# Lanelet2MapLoader~LanePlanner                          136.090970
# LanePlanner~BehaviorPlanner                           4475.614962
# BehaviorPlanner~VehicleInterface                       167.288768
# PointCloudMap~PointCloudMapLoader                      172.773692
# PointCloudMapLoader~NDTLocalizer                        93.531227
# NDTLocalizer~BehaviorPlanner                          5188.308715
# Visualizer~Lanelet2GlobalPlanner                      9757.520805
# Lanelet2GlobalPlanner~BehaviorPlanner                 3417.837939
# Lanelet2Map~Lanelet2MapLoader                         5128.584049
# Lanelet2MapLoader~BehaviorPlanner                     2162.656982
# EuclideanClusterSettings~EuclideanClusterDetector    12631.063824
# dtype: float64
